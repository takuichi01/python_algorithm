# %%
#グラフ のための外部パッケージ　NetworkX

import networkx as nx
graph = nx.Graph()
graph.add_edge(5,6)
graph.add_edge(6,7)

# %%
# %matplotlib inline
nx.draw_networkx(graph)

# %%
import random

def generate_graph(n, m):
  """ n個の頂点とm個の """
